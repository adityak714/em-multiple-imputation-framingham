# %%
## The implementation is very similar to the MICE algorithm for missing data imputation.

#  norm.pdf(30, a, scale=scale)*
# (np.sum(np.log(norm.pdf(df[['heartRate']], a_star, scale_star))) + np.log(---norm.pdf(30, a_star, scale=scale_star---)))

#########################################
#### IMPLEMENT THE ALGORITHM HERE ####
#########################################

# num_iters = 15
# a = np.zeros(num_iters)
# scale = np.zeros(num_iters)
# a[0], scale[0] = 75, 1.0

# for i in range(num_iters):
#     I = quad(integrand, 30, 160, args=(a[i], scale[i])) # returns [integral value, error estimate]
